# %%
## Code for reading external HuggingFace token, if necessary
def get_huggingface_token():
    f = open("huggingface_token.txt", "r")
    return (f.read())

# %%
from huggingface_hub import hf_hub_download

from datasets import load_dataset

dataset = load_dataset("Lemma-RCA-NEC/Product_Review_Preprocessed")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 5
#       1 from huggingface_hub import hf_hub_download
#       3 from datasets import load_dataset
# ----> 5 dataset = load_dataset("Lemma-RCA-NEC/Product_Review_Preprocessed")
#
# File ~/anaconda3/lib/python3.9/site-packages/datasets/load.py:1704, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, ignore_verifications, keep_in_memory, save_infos, revision, use_auth_token, task, streaming, **config_kwargs)
#    1701 ignore_verifications = ignore_verifications or save_infos
#    1703 # Create a dataset builder
# -> 1704 builder_instance = load_dataset_builder(
#    1705     path=path,
#    1706     name=name,
#    1707     data_dir=data_dir,
#    1708     data_files=data_files,
#    1709     cache_dir=cache_dir,
#    1710     features=features,
# ...
